# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Secundaria' 'Grado' 'Grado' 'Grado' 'Grado' 'Master' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Master' 'Secundaria'
#  'Doctorado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Master' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Master' 'Grado' 'Secundaria'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Master' 'Master' 'Secundaria' 'Doctorado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Master'
#  'Master' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Secundaria'
#  'Grado' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Master' 'Grado' 'Doctorado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Master' 'Grado'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Master' 'Bachillerato' 'Secundaria' 'Master' 'Grado'
#  'Doctorado' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Master'
#  'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Master'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Master'
#  'Bachillerato' 'Grado' 'Master' 'Bachillerato' 'Doctorado' 'Secundaria'
#  'Master' 'Bachillerato' 'Grado' 'Master' 'Secundaria' 'Secundaria'
#  'Master' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Doctorado' 'Master' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Doctorado' 'Grado' 'Secundaria'
#  'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Doctorado' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Master' 'Secundaria' 'Bachillerato' 'Master' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Doctorado' 'Grado' 'Doctorado' 'Grado' 'Grado' 'Grado'
#  'Doctorado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Master' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Doctorado' 'Bachillerato' 'Bachillerato' 'Master' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Doctorado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Master' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Master' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Master' 'Grado' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Doctorado'
#  'Grado' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Master' 'Bachillerato' 'Master'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Secundaria'
#  'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Master' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Master' 'Bachillerato' 'Grado' 'Master' 'Grado'
#  'Grado' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Grado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Master'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Doctorado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Master'
#  'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Master' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Master' 'Grado' 'Master' 'Secundaria'
#  'Master' 'Grado' 'Master' 'Secundaria' 'Secundaria' 'Master' 'Secundaria'
#  'Grado' 'Grado' 'Master' 'Grado' 'Secundaria' 'Secundaria' 'Grado'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Doctorado' 'Master'
#  'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()
